# %% [markdown]
# # Ingesta de datos para los ejercicios
#
# Vamos a crear el íncide que utilizaremos en los ejercicios e ingestar los datos necesarios para poder ejecutar las consultas.
#
# Vamos a almacenar recetas de cocina. Lo primero que vamos a ver es el formato de los datos que vamos a insertar.

# %%
import pandas as pd

df = pd.read_json("../../data/elasticsearch/recipes/recipes_copia.json", lines = True)
df.head()
# Out:
#            author          date  \
# 0  Hetty McKinnon     July 2021
# 1  Hetty McKinnon    April 2021
# 2    Katie Button  October 2016
# 3      Salma Hage    April 2016
# 4    Katie Button  October 2016
#
#                                          description  \
# 0  Grilled broccoli is one of life’s simple pleas...
# 1  This chile–oat crisp can be used like chile oi...
# 2  Esqueixar means “to shred” and that’s what’s d...
# 3  A colorful treat that I often made for my gran...
# 4  My chefs and I like to joke that this salad ha...
#
#                                          ingredients  \
# 0  [8 large eggs, 1½ lb. broccoli (about 3 small ...
# 1  [3 shallots, finely diced, 2 garlic cloves, fi...
# 2  [1 lemon, 1½ teaspoon honey, ½ teaspoon kosher...
# 3  [2⁄3 cup (5 fl oz/150 ml) pomegranate juice, 2...
# 4  [1 tablespoon honey, 1½ tablespoons reserve sh...
#
#                                         instructions  \
# 0  [Bring a medium pot of water to a boil. Carefu...
# 1  [To make the chili crisp, place the shallots, ...
# 2  [To make the lemon vinaigrette: To make the vi...
# 3  [Pour equal amounts of pomegranate juice into ...
# 4  [Whisk the honey, vinegar, and ½ teaspoon salt...
#
#                                         picture_link  \
# 0  https://assets.epicurious.com/photos/60ff0fc09...
# 1  https://assets.epicurious.com/photos/6107f447d...
# 2  https://assets.epicurious.com/photos/60fecf88d...
# 3  https://assets.epicurious.com/photos/60fee41bf...
# 4  https://assets.epicurious.com/photos/60fee610f...
#
#                                               rating  \
# 0  {'ratingValue': '0', 'bestRating': '4', 'worst...
# 1  {'ratingValue': '4', 'bestRating': '4', 'worst...
# 2  {'ratingValue': '0', 'bestRating': '4', 'worst...
# 3  {'ratingValue': '0', 'bestRating': '4', 'worst...
# 4  {'ratingValue': '0', 'bestRating': '4', 'worst...
#
#                                              summary  \
# 0  {'yield': '4 Servings', 'active-time': '22 min...
# 1                                               None
# 2  {'yield': 'Serves 4 as a main dish or 8 as a s...
# 3  {'yield': '6 ice pops (ice lollies)', 'active-...
# 4             {'yield': 'Serves 8 as a small plate'}
#
#                                                title  \
# 0   Egg Salad With Grilled Broccoli and Chili Crisp
# 1                             Chili Crisp With Oats
# 2  Esqueixada de Montaña (Cured Trout With Tomato...
# 3                       Pomegranate-Yogurt Ice Pops
# 4  Ensalada de Sandía y Tomate (Watermelon Tomato...
#
#                                                  url
# 0  http://www.epicurious.com/recipes/food/views/e...
# 1  http://www.epicurious.com/recipes/food/views/h...
# 2  http://www.epicurious.com/recipes/food/views/c...
# 3  http://www.epicurious.com/recipes/food/views/p...
# 4  http://www.epicurious.com/recipes/food/views/w...

# %% [markdown]
# ## Paso 1: Crear el índice
#
# Para crear el índice ejecuta la siguiente sentencia usando la herramienta dev tools de Kibana.
#
# `
# PUT recipes
# {
#     "aliases": {},
#     "settings" : {
#         "index" : {
#             "number_of_shards" : 4,
#             "number_of_replicas" : 1
#         },
#         "analysis": {
#           "analyzer": {
#             "autocomplete": {
#               "tokenizer": "autocomplete",
#               "filter": [
#                 "lowercase"
#               ]
#             },
#             "autocomplete_search": {
#               "tokenizer": "lowercase"
#             }
#           },
#           "tokenizer": {
#             "autocomplete": {
#               "type": "ngram",
#               "min_gram": 1,
#               "max_gram": 2,
#               "token_chars": [
#                 "letter"
#               ]
#             }
#           }
#         }
#     },
#     "mappings": {
#       "properties": {
#         "author": {
#           "type": "keyword",
#           "eager_global_ordinals": true,
#           "fields": {
#             "text": {
#               "type": "text"
#             }
#           }
#         },
#         "date": {
#           "type": "date",
#           "format": "[MMMM yyyy]",
#           "fields": {
#             "keyword": {
#               "type": "keyword"
#             }
#           }
#         },
#         "description": {
#           "type": "text",
#           "analyzer": "english"
#         },
#         "ingredients": {
#           "type": "text",
#           "analyzer": "english"
#         },
#         "instructions": {
#           "type": "text",
#           "analyzer": "english"
#         },
#         "picture_link": {
#           "type": "keyword"
#         },
#         "rating": {
#           "properties": {
#             "bestRating": {
#               "type": "float"
#             },
#             "prepareAgainPct": {
#               "type": "float"
#             },
#             "ratingValue": {
#               "type": "float"
#             },
#             "worstRating": {
#               "type": "float"
#             }
#           }
#         },
#         "recipe_id": {
#           "type": "text",
#           "fields": {
#             "keyword": {
#               "type": "keyword",
#               "ignore_above": 256
#             }
#           }
#         },
#         "summary": {
#           "properties": {
#             "active-time": {
#               "type": "keyword"
#             },
#             "total-time": {
#               "type": "keyword"
#             },
#             "yield": {
#               "type": "keyword"
#             }
#           }
#         },
#         "title": {
#           "type": "text",
#           "analyzer": "english",
#           "fields": {
#             "keyword": {
#               "type": "keyword"
#             },
#             "suggestion": {
#               "type": "completion",
#               "analyzer": "english",
#               "preserve_separators": false,
#               "preserve_position_increments": false,
#               "max_input_length": 50
#             },
#             "ngram": {
#             	"type": "text",
#             	"analyzer": "autocomplete",
#         		"search_analyzer": "autocomplete_search"
#             }
#           }
#         },
#         "url": {
#           "type": "text",
#           "fields": {
#             "keyword": {
#               "type": "keyword",
#               "ignore_above": 256
#             }
#           }
#         }
#       }
#     }
#   }
# `

# %% [markdown]
# ## Paso 2: Levantar Logstash
#
# Vamos a ingestar los datos usando Logsetash usando una imagen de docker para ejecutarlo:
#
# * Para que pueda encontrar el servicio de Elasticsearch vamos a añadir el conteneror a la red de nuestro laboratorio, `--network=curso-els-paradigma_default`. Puedes consultar la red creada por tu compose usando el comando `docker networks ls`
# * Montamos el volumen donde se encuentra nuestro fichero con el pipeline y los referenciamos a la carpeta del contenedor donde Logstash espera encontrar esa configuración, `-v /Users/rgarrote/desarrollo/datahack-nosql/work/data/elasticsearch/web_logs/pipeline/:/usr/share/logstash/pipeline/`.
# * Montamos el volumen donde dejaremos los ficheros de log a parsear. `-v /Users/rgarrote/desarrollo/datahack-nosql/work/data/elasticsearch/web_logs/data/:/tmp/data/`.

# %%
docker run --rm -it --network=curso-els-paradigma_default \
    -v /Users/rgarrote/desarrollo/cursoELS/curso-els-paradigma/work/data/elasticsearch/recipies/pipeline/:/usr/share/logstash/pipeline/ \
    -v /Users/rgarrote/desarrollo/cursoELS/curso-els-paradigma/work/data/elasticsearch/recipies/data/:/tmp/data/ \
docker.elastic.co/logstash/logstash:8.3.3

# %% [markdown]
# ## Paso 3: Ingestar los datos.
#
# Una vez que Logstash haya levantado y esté listo para procesar ficheros, copia el fichero que encontrarás en la ruta `work/data/elasticsearch/recipes/recipes.json` en la carpeta `workdata/elasticsearch/recipies/data`.
#
# Por cada documento ingestado se mostrará un punto en la pantalla.

# %% [markdown]
# ## Paso 4: Comprobar que el proceso se está realizando correctamente
#
# 1. Comprueba en Kibana que se ha ceado el íncide recipes.
# 2. Desde la sección de Index Management averigua cuantas recetas se han insertado en el índice recipes de Elasticsearch.
